# %%
# !pip freeze
# Out:
# absl_py==2.1.0+computecanada
# anyio==4.9.0+computecanada
# argon2_cffi==23.1.0+computecanada
# argon2_cffi_bindings==21.2.0+computecanada
# arrow==1.3.0+computecanada
# asttokens==3.0.0+computecanada
# async_lru==2.0.4+computecanada
# attrs==25.3.0+computecanada
# babel==2.17.0+computecanada
# beautifulsoup4==4.13.3+computecanada
# bleach==6.2.0+computecanada
# cachetools==5.5.1+computecanada
# certifi==2025.1.31+computecanada
# cffi==1.17.1+computecanada
# charset_normalizer==3.4.1+computecanada
# comm==0.2.2+computecanada
# debugpy==1.8.12+computecanada
# decorator==5.2.1+computecanada
# defusedxml==0.7.1+computecanada
# executing==2.2.0+computecanada
# fastjsonschema==2.21.1+computecanada
# filelock==3.18.0+computecanada
# fqdn==1.5.1+computecanada
# fsspec==2025.3.0+computecanada
# google_auth==2.38.0+computecanada
# google_auth_oauthlib==0.4.6+computecanada
# grpcio==1.67.0+computecanada
# h11==0.14.0+computecanada
# httpcore==1.0.7+computecanada
# httpx==0.28.1+computecanada
# ...

# %%
# !pip install --no-index openmim
# Out:
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/x86-64-v3, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/openmim-0.3.9+computecanada-py2.py3-none-any.whl
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/click-8.1.8+computecanada-py3-none-any.whl (from openmim)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/colorama-0.4.6+computecanada-py2.py3-none-any.whl (from openmim)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/model_index-0.1.11+computecanada-py3-none-any.whl (from openmim)
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/opendatalab-0.0.10+computecanada-py3-none-any.whl (from openmim)
# ...

# %%
# !pip install --no-index mmengine
# Out:
# Looking in links: /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/x86-64-v3, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/gentoo2023/generic, /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic
# Processing /cvmfs/soft.computecanada.ca/custom/python/wheelhouse/generic/mmengine-0.10.5+computecanada-py3-none-any.whl
# ...
